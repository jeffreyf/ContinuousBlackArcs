# %%
import numpy as np
import json
from import_data import *

# %%
json_files = get_json_files_in_directory('.')

# %%
json_files
# Out:
# [PosixPath('map_1.json'), PosixPath('map_2.json'), PosixPath('map_3.json')]

# %%
data = from_json_file(json_files[0])

# %%
with open('map_3.json') as file:
    data = json.load(file)

# %%
data
# Out:
# {'edges': [{'distance': '1.22', 'speed': 50, 'v1': 0, 'v2': 1},
#   {'distance': '0.14', 'speed': 50, 'v1': 3, 'v2': 4},
#   {'distance': '0.16', 'speed': 50, 'v1': 4, 'v2': 5},
#   {'distance': '0.11', 'speed': 50, 'v1': 5, 'v2': 6},
#   {'distance': '0.08', 'speed': 50, 'v1': 6, 'v2': 7},
#   {'distance': '0.14', 'speed': 50, 'v1': 7, 'v2': 8},
#   {'distance': '0.10', 'speed': 50, 'v1': 8, 'v2': 9},
#   {'distance': '0.18', 'speed': 50, 'v1': 9, 'v2': 10},
#   {'distance': '0.09', 'speed': 50, 'v1': 10, 'v2': 11},
#   {'distance': '0.13', 'speed': 50, 'v1': 11, 'v2': 12},
#   {'distance': '0.09', 'speed': 50, 'v1': 12, 'v2': 14},
#   {'distance': '0.06', 'speed': 50, 'v1': 14, 'v2': 15},
#   {'distance': '0.11', 'speed': 50, 'v1': 15, 'v2': 16},
#   {'distance': '0.31', 'speed': 50, 'v1': 16, 'v2': 17},
#   {'distance': '0.11', 'speed': 50, 'v1': 17, 'v2': 18},
#   {'distance': '0.12', 'speed': 50, 'v1': 18, 'v2': 19},
#   {'distance': '0.13', 'speed': 50, 'v1': 2, 'v2': 3},
# ...
